# %%
#importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load the dataset

# %%
df=pd.read_csv('housing.csv')

# %%
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
df.tail()
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking furnishingstatus
# 540              no              no        2      unfurnished
# 541              no              no        0   semi-furnished
# 542              no              no        0      unfurnished
# 543              no              no        0        furnished
# 544              no              no        0      unfurnished

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %% [markdown]
# ## 3.Perform Visualisations

# %% [markdown]
# ### Univariate analysis

# %%
plt.hist(df['price'])
# Out:
# (array([ 61., 163., 139.,  89.,  46.,  25.,  13.,   4.,   1.,   4.]),
#  array([ 1750000.,  2905000.,  4060000.,  5215000.,  6370000.,  7525000.,
#          8680000.,  9835000., 10990000., 12145000., 13300000.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['area'])
# Out:
# (array([ 73., 198., 117.,  88.,  39.,  15.,   8.,   5.,   0.,   2.]),
#  array([ 1650.,  3105.,  4560.,  6015.,  7470.,  8925., 10380., 11835.,
#         13290., 14745., 16200.]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['furnishingstatus'])
# Out:
# (array([140.,   0.,   0.,   0.,   0., 227.,   0.,   0.,   0., 178.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Bivariate analysis

# %%
plt.plot(df['price'], df['area'])
plt.title('Line Chart of price and area')
plt.xlabel('price')
plt.ylabel('area')
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.subplot(1,2,1)
plt.bar(df['furnishingstatus'],df['price'])
plt.xlabel('furnishingstatus')
plt.ylabel('price')
plt.title('furnishingstatus vs price')

plt.subplot(1,2,2)
plt.bar(df['bedrooms'],df['price'])
plt.xlabel('bedrooms')
plt.ylabel('price')
plt.title('bedrooms vs price')
# Out:
# Text(0.5, 1.0, 'bedrooms vs price')

# %% [markdown]
# ### Multivariate analysis

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20848\195471851.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %% [markdown]
# ## 4. Perform descriptive statistics on the dataset

# %%
df.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
df.mean()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20848\3698961737.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# price        4.766729e+06
# area         5.150541e+03
# bedrooms     2.965138e+00
# bathrooms    1.286239e+00
# stories      1.805505e+00
# parking      6.935780e-01
# dtype: float64

# %%
df.median()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20848\530051474.py:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# price        4340000.0
# area            4600.0
# bedrooms           3.0
# bathrooms          1.0
# stories            2.0
# parking            0.0
# dtype: float64

# %%
df.mode()
# Out:
#      price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  3500000  6000.0       3.0        1.0      2.0      yes        no       no
# 1  4200000     NaN       NaN        NaN      NaN      NaN       NaN      NaN
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no              no      0.0   semi-furnished
# 1             NaN             NaN      NaN              NaN

# %%
df.var()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20848\1568254755.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.var()
# price        3.498544e+12
# area         4.709512e+06
# bedrooms     5.447383e-01
# bathrooms    2.524757e-01
# stories      7.525432e-01
# parking      7.423300e-01
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20848\3390915376.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# price        1.870440e+06
# area         2.170141e+03
# bedrooms     7.380639e-01
# bathrooms    5.024696e-01
# stories      8.674925e-01
# parking      8.615858e-01
# dtype: float64

# %% [markdown]
# ## 5. Check for Missing values and deal with them

# %%
df.isna()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
df.isnull().any()
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# furnishingstatus    False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
df.shape
# Out:
# (545, 12)

# %% [markdown]
# ## 6. Find the outliers and replace them outliers

# %%
plt.boxplot(df.area)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1852fb7e0b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1852fb7e3b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1852fb7de10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1852fb7e8f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1852fb7eb90>],
#  'means': []}

# %%
plt.boxplot(df.price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1852fbf2290>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1852fbf26b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1852fbf1ff0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1852fbf2bf0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1852fbf2e90>],
#  'means': []}

# %%
perc95=df.price.quantile(0.95)
perc95
# Out:
# 8400000.0

# %%
df=df[df.price<=perc95]
plt.boxplot(df.price)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1852ffc95d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1852ffc9b10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1852ffc9330>],
#  'medians': [<matplotlib.lines.Line2D at 0x1852ffca050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1852ffca2f0>],
#  'means': []}

# %%
perc99=df.area.quantile(0.99)
perc99
# Out:
# 11456.6

# %%
df=df[df.area<=perc99]
plt.boxplot(df.area)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x18530040cd0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x18530041210>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x18530040a30>],
#  'medians': [<matplotlib.lines.Line2D at 0x18530041750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x185300419f0>],
#  'means': []}

# %% [markdown]
# ## 7. Check for Categorical columns and perform encoding

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 27  8400000  8875         3          1        1      yes        no       no
# 28  8400000  7950         5          2        2      yes        no      yes
# 29  8400000  5500         4          2        2      yes        no      yes
# 30  8400000  7475         3          2        4      yes        no       no
# 31  8400000  7000         3          1        4      yes        no       no
#
#    hotwaterheating airconditioning  parking furnishingstatus
# 27              no              no        1   semi-furnished
# 28             yes              no        2      unfurnished
# 29              no             yes        1   semi-furnished
# 30              no             yes        2      unfurnished
# 31              no             yes        2   semi-furnished

# %%
#categorical columns are mainroad,guestroom,basement,hotwatering,airconditioning,furnishing status
#furnishing status ordinary data--one hot encoding
#reamining all label encoding
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df.mainroad=le.fit_transform(df.mainroad)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad guestroom basement  \
# 27  8400000  8875         3          1        1         1        no       no
# 28  8400000  7950         5          2        2         1        no      yes
# 29  8400000  5500         4          2        2         1        no      yes
# 30  8400000  7475         3          2        4         1        no       no
# 31  8400000  7000         3          1        4         1        no       no
#
#    hotwaterheating airconditioning  parking furnishingstatus
# 27              no              no        1   semi-furnished
# 28             yes              no        2      unfurnished
# 29              no             yes        1   semi-furnished
# 30              no             yes        2      unfurnished
# 31              no             yes        2   semi-furnished

# %%
df.guestroom=le.fit_transform(df.guestroom)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom basement  \
# 27  8400000  8875         3          1        1         1          0       no
# 28  8400000  7950         5          2        2         1          0      yes
# 29  8400000  5500         4          2        2         1          0      yes
# 30  8400000  7475         3          2        4         1          0       no
# 31  8400000  7000         3          1        4         1          0       no
#
#    hotwaterheating airconditioning  parking furnishingstatus
# 27              no              no        1   semi-furnished
# 28             yes              no        2      unfurnished
# 29              no             yes        1   semi-furnished
# 30              no             yes        2      unfurnished
# 31              no             yes        2   semi-furnished

# %%
df.basement=le.fit_transform(df.basement)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 27  8400000  8875         3          1        1         1          0
# 28  8400000  7950         5          2        2         1          0
# 29  8400000  5500         4          2        2         1          0
# 30  8400000  7475         3          2        4         1          0
# 31  8400000  7000         3          1        4         1          0
#
#     basement hotwaterheating airconditioning  parking furnishingstatus
# 27         0              no              no        1   semi-furnished
# 28         1             yes              no        2      unfurnished
# 29         1              no             yes        1   semi-furnished
# 30         0              no             yes        2      unfurnished
# 31         0              no             yes        2   semi-furnished

# %%
df.hotwaterheating=le.fit_transform(df.hotwaterheating)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 27  8400000  8875         3          1        1         1          0
# 28  8400000  7950         5          2        2         1          0
# 29  8400000  5500         4          2        2         1          0
# 30  8400000  7475         3          2        4         1          0
# 31  8400000  7000         3          1        4         1          0
#
#     basement  hotwaterheating airconditioning  parking furnishingstatus
# 27         0                0              no        1   semi-furnished
# 28         1                1              no        2      unfurnished
# 29         1                0             yes        1   semi-furnished
# 30         0                0             yes        2      unfurnished
# 31         0                0             yes        2   semi-furnished

# %%
df.airconditioning=le.fit_transform(df.airconditioning)

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 27  8400000  8875         3          1        1         1          0
# 28  8400000  7950         5          2        2         1          0
# 29  8400000  5500         4          2        2         1          0
# 30  8400000  7475         3          2        4         1          0
# 31  8400000  7000         3          1        4         1          0
#
#     basement  hotwaterheating  airconditioning  parking furnishingstatus
# 27         0                0                0        1   semi-furnished
# 28         1                1                0        2      unfurnished
# 29         1                0                1        1   semi-furnished
# 30         0                0                1        2      unfurnished
# 31         0                0                1        2   semi-furnished

# %%
df_main=pd.get_dummies(df,columns=['furnishingstatus'])

# %%
df_main.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 27  8400000  8875         3          1        1         1          0
# 28  8400000  7950         5          2        2         1          0
# 29  8400000  5500         4          2        2         1          0
# 30  8400000  7475         3          2        4         1          0
# 31  8400000  7000         3          1        4         1          0
#
#     basement  hotwaterheating  airconditioning  parking  \
# 27         0                0                0        1
# 28         1                1                0        2
# 29         1                0                1        1
# 30         0                0                1        2
# 31         0                0                1        2
#
#     furnishingstatus_furnished  furnishingstatus_semi-furnished  \
# 27                           0                                1
# 28                           0                                0
# ...

# %% [markdown]
# ## 8. Split the data into dependent and independent variables

# %%
#dependent variable is price
y=df_main['price']

# %%
y.head()
# Out:
# 27    8400000
# 28    8400000
# 29    8400000
# 30    8400000
# 31    8400000
# Name: price, dtype: int64

# %%
#reamining are independent variables
X=df_main.drop(columns=['price'],axis=1)

# %%
X.head()
# Out:
#     area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 27  8875         3          1        1         1          0         0
# 28  7950         5          2        2         1          0         1
# 29  5500         4          2        2         1          0         1
# 30  7475         3          2        4         1          0         0
# 31  7000         3          1        4         1          0         0
#
#     hotwaterheating  airconditioning  parking  furnishingstatus_furnished  \
# 27                0                0        1                           0
# 28                1                0        2                           0
# 29                0                1        1                           0
# 30                0                1        2                           0
# 31                0                1        2                           0
#
#     furnishingstatus_semi-furnished  furnishingstatus_unfurnished
# ...

# %% [markdown]
# ## 9. Scale the independent variables

# %%
name=X.columns

# %%
name
# Out:
# Index(['area', 'bedrooms', 'bathrooms', 'stories', 'mainroad', 'guestroom',
#        'basement', 'hotwaterheating', 'airconditioning', 'parking',
#        'furnishingstatus_furnished', 'furnishingstatus_semi-furnished',
#        'furnishingstatus_unfurnished'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
X_scaled=scale.fit_transform(X)

# %%
X_scaled
# Out:
# array([[0.73799796, 0.4       , 0.        , ..., 0.        , 1.        ,
#         0.        ],
#        [0.64351379, 0.8       , 0.5       , ..., 0.        , 0.        ,
#         1.        ],
#        [0.39325843, 0.6       , 0.5       , ..., 0.        , 1.        ,
#         0.        ],
#        ...,
#        [0.20122574, 0.2       , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.12870276, 0.4       , 0.        , ..., 1.        , 0.        ,
#         0.        ],
#        [0.2247191 , 0.4       , 0.        , ..., 0.        , 0.        ,
#         1.        ]])

# %%
X=pd.DataFrame(X_scaled,columns=name)

# %%
X
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 0    0.737998       0.4        0.0  0.000000       1.0        0.0       0.0
# 1    0.643514       0.8        0.5  0.333333       1.0        0.0       1.0
# 2    0.393258       0.6        0.5  0.333333       1.0        0.0       1.0
# 3    0.594995       0.4        0.5  1.000000       1.0        0.0       0.0
# 4    0.546476       0.4        0.0  1.000000       1.0        0.0       0.0
# ..        ...       ...        ...       ...       ...        ...       ...
# 507  0.137896       0.2        0.0  0.000000       1.0        0.0       1.0
# 508  0.076609       0.4        0.0  0.000000       0.0        0.0       0.0
# 509  0.201226       0.2        0.0  0.000000       1.0        0.0       0.0
# 510  0.128703       0.4        0.0  0.000000       0.0        0.0       0.0
# 511  0.224719       0.4        0.0  0.333333       1.0        0.0       0.0
#
# ...

# %% [markdown]
# ## 10. Split the data into training and testing

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
X_train.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 297  0.235955       0.4        0.0  0.333333       1.0        0.0       0.0
# 311  0.248212       0.2        0.0  0.000000       1.0        0.0       0.0
# 298  0.245148       0.2        0.0  0.333333       1.0        1.0       1.0
# 71   0.505618       0.4        0.5  0.000000       1.0        0.0       1.0
# 170  0.249745       0.4        0.0  0.333333       0.0        1.0       1.0
#
#      hotwaterheating  airconditioning  parking  furnishingstatus_furnished  \
# 297              0.0              0.0      0.0                         1.0
# 311              0.0              0.0      0.0                         0.0
# 298              0.0              0.0      0.0                         0.0
# 71               0.0              1.0      0.0                         0.0
# 170              0.0              1.0      0.0                         0.0
#
# ...

# %%
X_test.head()
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 283  0.403473       0.2        0.0  0.000000       1.0        0.0       0.0
# 100  0.426762       0.6        0.0  1.000000       1.0        1.0       0.0
# 37   0.972932       0.4        0.0  0.000000       1.0        0.0       1.0
# 46   0.266599       0.6        0.5  0.333333       1.0        0.0       0.0
# 374  0.050562       0.4        0.0  0.666667       1.0        0.0       0.0
#
#      hotwaterheating  airconditioning   parking  furnishingstatus_furnished  \
# 283              0.0              1.0  0.000000                         0.0
# 100              0.0              0.0  0.000000                         0.0
# 37               0.0              1.0  0.333333                         1.0
# 46               1.0              0.0  0.000000                         0.0
# 374              0.0              0.0  0.000000                         1.0
#
# ...

# %%
y_train
# Out:
# 329    3990000
# 343    3850000
# 330    3990000
# 100    6230000
# 201    4900000
#         ...
# 355    3773000
# 224    4760000
# 148    5600000
# 76     6650000
# 203    4900000
# Name: price, Length: 409, dtype: int64

# %%
y_test
# Out:
# 315    4095000
# 131    5810000
# 64     7000000
# 75     6650000
# 407    3465000
#         ...
# 341    3850000
# 412    3430000
# 85     6510000
# 220    4795000
# 89     6440000
# Name: price, Length: 103, dtype: int64

# %% [markdown]
# ## 11. Build the Model

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## 12. Train the model

# %%
X_train
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 297  0.235955       0.4        0.0  0.333333       1.0        0.0       0.0
# 311  0.248212       0.2        0.0  0.000000       1.0        0.0       0.0
# 298  0.245148       0.2        0.0  0.333333       1.0        1.0       1.0
# 71   0.505618       0.4        0.5  0.000000       1.0        0.0       1.0
# 170  0.249745       0.4        0.0  0.333333       0.0        1.0       1.0
# ..        ...       ...        ...       ...       ...        ...       ...
# 323  0.674157       0.4        0.0  0.000000       1.0        0.0       0.0
# 192  0.877426       0.2        0.0  0.000000       1.0        0.0       0.0
# 117  0.481103       0.4        0.0  0.666667       1.0        0.0       0.0
# 47   0.487232       0.4        0.5  0.666667       1.0        0.0       0.0
# 172  0.383044       0.6        0.0  0.333333       1.0        0.0       0.0
#
# ...

# %%
y_train
# Out:
# 329    3990000
# 343    3850000
# 330    3990000
# 100    6230000
# 201    4900000
#         ...
# 355    3773000
# 224    4760000
# 148    5600000
# 76     6650000
# 203    4900000
# Name: price, Length: 409, dtype: int64

# %% [markdown]
# ## 13. Test the model

# %%
score = model.score(X_test, y_test)

# %%
X_test
# Out:
#          area  bedrooms  bathrooms   stories  mainroad  guestroom  basement  \
# 283  0.403473       0.2        0.0  0.000000       1.0        0.0       0.0
# 100  0.426762       0.6        0.0  1.000000       1.0        1.0       0.0
# 37   0.972932       0.4        0.0  0.000000       1.0        0.0       1.0
# 46   0.266599       0.6        0.5  0.333333       1.0        0.0       0.0
# 374  0.050562       0.4        0.0  0.666667       1.0        0.0       0.0
# ..        ...       ...        ...       ...       ...        ...       ...
# 309  0.156282       0.2        0.5  0.000000       1.0        0.0       1.0
# 379  0.098059       0.4        0.0  0.333333       1.0        0.0       1.0
# 56   0.674157       0.4        0.5  0.666667       1.0        0.0       0.0
# 188  0.658836       0.6        0.0  1.000000       1.0        0.0       1.0
# 60   0.707865       0.8        1.0  0.333333       1.0        0.0       0.0
#
# ...

# %%
y_test
# Out:
# 315    4095000
# 131    5810000
# 64     7000000
# 75     6650000
# 407    3465000
#         ...
# 341    3850000
# 412    3430000
# 85     6510000
# 220    4795000
# 89     6440000
# Name: price, Length: 103, dtype: int64

# %%
score
# Out:
# 0.6960731204127022

# %%
predictions = model.predict(X_test)

# %%
predictions
# Out:
# array([4558536.19817961, 5688700.10765186, 6539724.59994836,
#        5106349.92651298, 3878563.33656656, 5597260.43783397,
#        5679278.83542114, 6746954.64966268, 3910085.72388562,
#        3625245.16094622, 5000866.27175142, 4560806.46935538,
#        3993584.70791095, 4246030.82732184, 4303882.60735605,
#        3013930.41176584, 4745805.58246798, 2920662.946934  ,
#        5561927.65895442, 4728482.63656298, 3716985.72942767,
#        5267172.68513737, 3892640.94347015, 3554198.94755982,
#        4677622.44478293, 4505865.71300763, 4014079.42333905,
#        3992011.2568889 , 5658266.97777234, 3278814.0625248 ,
#        3150142.27568921, 3987428.86796867, 4589537.22386567,
#        4086906.40899677, 5402264.37824753, 3656853.04008799,
#        5218769.17728743, 6017376.31172796, 4202446.03448069,
#        5399479.03501712, 5118427.70841732, 4664168.12684039,
#        5695402.16188678, 4934728.29688431, 5782876.63203187,
# ...

# %% [markdown]
# ## 14. Measure the performance using Metrics

# %%
from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error
y_pred = model.predict(X_test)

# %%
error=y_test-y_pred

# %%
error
# Out:
# 315   -4.635362e+05
# 131    1.212999e+05
# 64     4.602754e+05
# 75     1.543650e+06
# 407   -4.135633e+05
#            ...
# 341   -5.960191e+05
# 412    1.980258e+04
# 85    -4.158478e+05
# 220   -2.548617e+06
# 89    -4.615425e+05
# Name: price, Length: 103, dtype: float64

# %%
se=error*error

# %%
se
# Out:
# 315    2.148658e+11
# 131    1.471366e+10
# 64     2.118534e+11
# 75     2.382856e+12
# 407    1.710346e+11
#            ...
# 341    3.552388e+11
# 412    3.921423e+08
# 85     1.729294e+11
# 220    6.495451e+12
# 89     2.130215e+11
# Name: price, Length: 103, dtype: float64

# %%
mse=np.mean(se)

# %%
mse
# Out:
# 590421663235.8289

# %%
mse2=mean_squared_error(y_test,y_pred)

# %%
mse2
# Out:
# 590421663235.8289

# %%
mae=mean_absolute_error(y_test,y_pred)

# %%
mae
# Out:
# 569032.3072899253

# %%
rmse=np.sqrt(mse2)

# %%
rmse
# Out:
# 768389.0051502747

# %%
r2=r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.6960731204127022
